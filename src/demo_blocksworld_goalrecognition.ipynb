# %%
import os
os.environ["OPENAI_API_KEY"] = 'sk-xxx'
os.environ["OPENAI_API_BASE"] ='https://api.deepseek.com'

# %%
from functools import partial
from argparse import Namespace
from logot.models import gpt
from logot.methods.solver import solve, solve_standard_prompt, solve_cot_prompt

from logot.tasks.blocksworld import BWGoalRecogTask
CACHE_FILE = './tmp/bwgoalrecog_demo_cache.h5'
VERBOSE = 3
# METHOD = 'logot'
# METHOD = 'standard_prompt'
METHOD = 'cot'

task = BWGoalRecogTask()
_args = {
    'backend': "deepseek-chat", 
    'temperature': 0.7, 
    'cache_file': CACHE_FILE,
}
args = Namespace(**_args)
# Out:
# OPENAI_API_BASE is set to https://api.deepseek.com

# %%
IDX = 0
if METHOD == 'logot':
    res = solve(args, task, IDX, VERBOSE)
elif METHOD == 'standard_prompt':
    res = solve_standard_prompt(args, task, IDX, VERBOSE)
elif METHOD == 'cot':
    res = solve_cot_prompt(args, task, IDX, VERBOSE)    
else:
    raise NotImplementedError(f'{METHOD} not implemented.')
# Out:
# Retrive result from cache
# ========DEBUGGING IN SOLVE========
# x
# ('The navy block is on top of the blue block. The gray block is on top of the navy block. The blue block is on the table. The indigo block is clear. The indigo block is on the table. The white block is clear. The white block is on the table. The gray block is clear.', 'Jane moves the gray block from the navy block onto the table. Jane moves the navy block from the blue block onto the table.', 'the white block is not on the table and the blue block is on top of the gray block')
# prompt
# Given:
# - An initial state describing the positions and properties of blocks.
# - A sequence of observed actions.
# - A goal query in the form of a partial or complete final configuration.
# Your task is to determine if the sequence of actions is consistent with an optimal plan toward achieving the queried goal.
#
# Step-by-step reasoning:
#
# Step 1: Parse the initial state and reconstruct the block configuration (what is on what, what is clear, what is on the table).
#
# Step 2: Apply each observed action sequentially to update the world state.
#
# Step 3: After all actions, check if the resulting state is consistent with a prefix of any optimal plan toward the queried goal. Consider whether achieving the goal from the current state (after observed actions) would involve unnecessary steps or if a more efficient path could have been followed.
#
# Step 4: If the observed actions could be part of an optimal plan that leads to the queried goal, output “True”; otherwise, “False”.
#
# Now let’s work through an example:
#
# Input:
# state:
# The navy block is on top of the blue block. The gray block is on top of the navy block. The blue block is on the table. The indigo block is clear. The indigo block is on the table. The white block is clear. The white block is on the table. The gray block is clear.
# observations:
# Jane moves the gray block from the navy block onto the table. Jane moves the navy block from the blue block onto the table.
# query:
# the white block is not on the table and the blue block is on top of the gray block
#
# Step 1: Initial state reconstruction:
# - blue is on the table, navy is on blue, gray is on navy → forming a tower: gray → navy → blue → table
# - gray is clear
# - indigo and white are both clear and on the table
#
# Step 2: Apply observations:
# 1) gray is moved from navy to table → now navy is clear; gray is on table
# 2) navy is moved from blue to table → now blue is clear; navy is on table
#
# New configuration:
# - blue is on table and clear
# - gray is on table and clear
# - navy is on table and clear
# - indigo is clear on table
# - white is clear on table
#
# Step 3: Query: “white block is not on the table” → this is not satisfied, since no move involved white
# “blue block is on top of the gray block” → this is also not satisfied; blue and gray are on the table
#
# Thus, the actions cannot be a prefix of an optimal plan to achieve this query.
#
# %
# False
#
#
# The new input is as follows:
# Input:
# state:
# The navy block is on top of the blue block. The gray block is on top of the navy block. The blue block is on the table. The indigo block is clear. The indigo block is on the table. The white block is clear. The white block is on the table. The gray block is clear.
#
# observations:
# Jane moves the gray block from the navy block onto the table. Jane moves the navy block from the blue block onto the table.
#
# query:
# the white block is not on the table and the blue block is on top of the gray block
#
#
# Use the same step-by-step reasoning to get the result.
#
# gpt_res
# Let's go through the steps again for the given input to ensure clarity and correctness.
#
# ### Step 1: Initial State Reconstruction
# From the initial state description:
# - The blue block is on the table.
# - The navy block is on top of the blue block.
# - The gray block is on top of the navy block.
# - The gray block is clear (nothing on top of it).
# - The indigo block is clear and on the table.
# - The white block is clear and on the table.
#
# This gives us the following initial configuration:
# - Tower 1: gray → navy → blue → table
# - Tower 2: indigo → table
# - Tower 3: white → table
#
# ### Step 2: Apply Observed Actions
# **Observation 1:** Jane moves the gray block from the navy block onto the table.
# - Before: gray is on navy (navy is under gray).
# - After: gray is moved to the table, so navy is now clear (nothing on top of it).
# - New configuration:
#   - navy → blue → table (navy is now clear)
#   - gray → table (gray is now clear)
#   - indigo → table
#   - white → table
#
# **Observation 2:** Jane moves the navy block from the blue block onto the table.
# - Before: navy is on blue (blue is under navy).
# - After: navy is moved to the table, so blue is now clear (nothing on top of it).
# - New configuration:
#   - blue → table (blue is now clear)
#   - navy → table (navy is now clear)
#   - gray → table (gray is now clear)
#   - indigo → table
#   - white → table
#
# ### Step 3: Check Query Consistency
# The query is: "the white block is not on the table and the blue block is on top of the gray block."
#
# Let's break this down:
# 1. "the white block is not on the table":
#    - In the current state after observations, the white block is still on the table. This part of the query is not satisfied.
# 2. "the blue block is on top of the gray block":
#    - In the current state, the blue block is on the table, and the gray block is also on the table. They are not stacked in any way. This part of the query is also not satisfied.
#
# Since neither part of the query is satisfied after the observed actions, the observed actions cannot be part of an optimal plan to achieve the queried goal.
#
# ### Step 4: Conclusion
# The observed actions do not lead to a state that is consistent with a prefix of any optimal plan toward the queried goal.
#
# ### Final Answer:
# False
# ==================================

# %%
print('Test input:')
print(task.get_input(IDX))
print()
print('Test output:')
print(res)
print()
print(f'Valid: {task.test_output(IDX, res)}')
# Out:
# Test input:
# ('The navy block is on top of the blue block. The gray block is on top of the navy block. The blue block is on the table. The indigo block is clear. The indigo block is on the table. The white block is clear. The white block is on the table. The gray block is clear.', 'Jane moves the gray block from the navy block onto the table. Jane moves the navy block from the blue block onto the table.', 'the white block is not on the table and the blue block is on top of the gray block')
#
# Test output:
# False
#
# Valid: False
